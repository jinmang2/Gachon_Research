# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
% matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

# %%
df = pd.read_csv("df_104.csv")

# %%
df.head()
# Out:
#    code  iso         country    1990    1991    1992    1993    1994    1995  \
# 0     8  ALB         Albania  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1    16  ASM  American Samoa  8.6824  8.6824  8.6824  8.6824  8.6824  8.6824
# 2    32  ARG       Argentina  0.1091  0.1118  0.1207  0.1270  0.1897  0.1897
# 3    36  AUS       Australia  0.5882  0.7173  0.7250  0.7380  0.7801  0.7802
# 4    44  BHS     The Bahamas  0.0988  0.0988  0.0988  0.0988  0.0988  0.1047
#
#      1996            ...                 2009     2010     2011     2012  \
# 0  0.3830            ...               0.8138   0.8138   0.8138   0.8138
# 1  8.6824            ...               8.6824   8.6840   8.6840   8.6840
# 2  0.1897            ...               0.8631   0.9310   0.9310   0.9317
# 3  0.7803            ...              11.0652  11.3887  11.3887  11.3920
# 4  0.1047            ...               0.2012   0.2012   0.2012   0.2012
#
#       2013     2014     2015  Code         Income group  \
# ...

# %%
type(df.columns[6])
# Out:
# str

# %%
df["Income group"].value_counts()
# Out:
# High income            41
# Upper middle income    32
# Lower middle income    23
# Low income              8
# Name: Income group, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Europe & Central Asia         28
# Latin America & Caribbean     24
# East Asia & Pacific           22
# Sub-Saharan Africa            16
# Middle East & North Africa     9
# South Asia                     3
# North America                  2
# Name: Region, dtype: int64

# %%
df["Income group"].replace({'Upper middle income':'middle', 'High income':'high', 'Lower middle income':'low',
       'Low income':'low'}, inplace=True)
df["Region"].replace({'Europe & Central Asia':'ECA&NA', 'East Asia & Pacific':'EAP',
       'Latin America & Caribbean':'LAC', 'Middle East & North Africa':'MENA',
       'South Asia':'SA', 'Sub-Saharan Africa':'SA', 'North America':"ECA&NA"}, inplace=True)

# %%
df["Income group"].value_counts()
# Out:
# high      41
# middle    32
# low       31
# Name: Income group, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# ECA&NA    30
# LAC       24
# EAP       22
# SA        19
# MENA       9
# Name: Region, dtype: int64

# %%
import convergence

# %%
data = df[df.columns[1:]]
ca_total = convergence.ConvergenceAnalysis(data)
ca_high = convergence.ConvergenceAnalysis(data[data["Income group"]=="high"])
ca_middle = convergence.ConvergenceAnalysis(data[data["Income group"]=="middle"])
ca_low = convergence.ConvergenceAnalysis(data[data["Income group"]=="low"])
ca_eap = convergence.ConvergenceAnalysis(data[data["Region"]=="EAP"])
ca_ecana = convergence.ConvergenceAnalysis(data[data["Region"]=="ECA&NA"])
ca_lac = convergence.ConvergenceAnalysis(data[data["Region"]=="LAC"])
ca_mena = convergence.ConvergenceAnalysis(data[data["Region"]=="MENA"])
ca_sa = convergence.ConvergenceAnalysis(data[data["Region"]=="SA"])
# Out:
# Version 1.0.0
# Welcome. This Class works for ConvergenceAnalysis.
# You can access dataframe by these METHODS
#   : df, t_df
# also, You can access as pd.Series by these METHODS
#   : mean, var, std, cv, sigma, std_s, cv_s (_s means, "sample")
#     rank_var, gamma_var, gamma
# and You can access as pd.DataFrame by thes METHODS
#   : df_rank, df_gamma
# Finally, You can get three CAGR by these METHODS
#   : mean_cagr, sigma_cagr, gamma_cagr
#
# This Class has 4 Functions following as
#   : t_test(alpha=0.05, r=0), chi_square_test(r=0)
#     get_measure_table(name, measure), get_index_table(name)
# Version 1.0.0
# Welcome. This Class works for ConvergenceAnalysis.
# You can access dataframe by these METHODS
#   : df, t_df
# also, You can access as pd.Series by these METHODS
#   : mean, var, std, cv, sigma, std_s, cv_s (_s means, "sample")
#     rank_var, gamma_var, gamma
# and You can access as pd.DataFrame by thes METHODS
#   : df_rank, df_gamma
# ...

# %%
ca_total.t_test()
ca_high.t_test()
ca_middle.t_test()
ca_low.t_test()
ca_eap.t_test()
ca_ecana.t_test()
ca_lac.t_test()
ca_mena.t_test()
ca_sa.t_test()
# Out:
# Do T-Test. Get a P-value.
# If you want, You can get statistic values by these METHODS
#   : alpha, z_crit, dof(degree of freedom)
# And You can get pd.Series by these METHODS
#   : z, p_value, t_lower, t_upper
# Do T-Test. Get a P-value.
# If you want, You can get statistic values by these METHODS
#   : alpha, z_crit, dof(degree of freedom)
# And You can get pd.Series by these METHODS
#   : z, p_value, t_lower, t_upper
# Do T-Test. Get a P-value.
# If you want, You can get statistic values by these METHODS
#   : alpha, z_crit, dof(degree of freedom)
# And You can get pd.Series by these METHODS
#   : z, p_value, t_lower, t_upper
# Do T-Test. Get a P-value.
# If you want, You can get statistic values by these METHODS
#   : alpha, z_crit, dof(degree of freedom)
# And You can get pd.Series by these METHODS
#   : z, p_value, t_lower, t_upper
# Do T-Test. Get a P-value.
# If you want, You can get statistic values by these METHODS
#   : alpha, z_crit, dof(degree of freedom)
# ...

# %%
ca_total.chi_square_test()
ca_high.chi_square_test()
ca_middle.chi_square_test()
ca_low.chi_square_test()
ca_eap.chi_square_test()
ca_ecana.chi_square_test()
ca_lac.chi_square_test()
ca_mena.chi_square_test()
ca_sa.chi_square_test()
# Out:
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# You can get pd.Series by these METHODS
#   : W1, r, chi_squared, chi_p_value, W2
# Do Chi-Square Test. Get a P_value.
# ...

# %%
# Figure 1.
fig = plt.figure()
fig.set_size_inches((12,7))
ca = ca_total
plt.plot(ca.mean, marker="D", mew=5, lw=3, 
         label="Total({})\nCAGR = {:.3}%".format(ca.dof+1, ca.mean_cagr*100), color = (0.2,0.2,1,1))
lgd = plt.legend(shadow=True, fancybox=True, fontsize=12)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(1), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,6.5))
f = ca_total
f1 = ca_high
f2 = ca_middle
f3 = ca_low
plt.plot(f.mean, marker="D", mew=5, lw=3, label="Total({})\nCAGR = {}%".format(f.dof+1, round(f.mean_cagr*100,2)), \
         color = (0.2,0.2,1,1))
plt.plot(f1.mean, marker="s", mfc='none', ms=12, mew=2, label="High_income({})\nCAGR = {}%".format(f1.dof+1, round(f1.mean_cagr*100,2)), \
         color = "#FF0000", linestyle = "--")
plt.plot(f2.mean, marker="^", mfc='none', ms=12, mew=2, lw=3, \
         label="Middle_income({})\nCAGR = {}%".format(f2.dof+1, round(f2.mean_cagr*100,2)), \
         color = (0.9,0.7,0,1), linestyle = "--")
plt.plot(f3.mean, marker="o", mfc='none', ms=12, mew=2, lw=3, 
         label="Low_income({})\nCAGR = {}%".format(f3.dof+1, round(f3.mean_cagr*100,2)), \
         color = (0.5,0.7,0,1), linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(2), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,6.5))
f = ca_eap
f1 = ca_ecana
f2 = ca_lac
f3 = ca_mena
f4 = ca_sa
plt.plot(f.mean, marker="s", mfc='none', ms=12, mew=2, lw=3, label="EAP({})\nCAGR = {}%".format(f.dof+1,round(f.mean_cagr*100,2)))
plt.plot(f1.mean, marker="^", mfc='none', ms=12, mew=2, lw=3, label="ECA&NA({})\nCAGR = {}%".format(f1.dof+1,round(f1.mean_cagr*100,2)), \
         linestyle = "--")
plt.plot(f2.mean, marker="x", ms=2, mew=15, lw=3, label="LAC({})\nCAGR = {}%".format(f2.dof+1,round(f2.mean_cagr*100,2))
         , color = (0.5,0.5,0.5,1),linestyle = "--")
plt.plot(f3.mean, marker="D", mfc='none', ms=12, mew=2, lw=3, label="MENA({})\nCAGR = {}%".format(f3.dof+1,round(f3.mean_cagr*100,2))
         , color = "#FFBE0A", linestyle = "--")
plt.plot(f4.mean, marker="+", ms=2, mew=15, lw=3, label="SA({})\nCAGR = {}%".format(f4.dof+1,round(f4.mean_cagr*100,2)),
         color = "#64CD3C" , linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(3), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,7))
f = ca_total
f1 = ca_total
plt.plot(f.sigma, marker="s", mew=5, lw=3, label="Sigma\nCAGR = {}%".format(round(f.sigma_cagr*100,2)))
plt.plot(f1.gamma, marker="s", mfc='none', ms=12, mew=2, lw=3, label="Gamma\nCAGR = {}%".format(round(f1.gamma_cagr*100,2)),
         linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, fontsize=12)
#lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Normalized Index', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(4), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,6.5))
f = ca_total
f1 = ca_high
f2 = ca_middle
f3 = ca_low
plt.plot(f.sigma, marker="D", mew=5, lw=3, label="Total({})\nCAGR = {}%".format(f.dof+1, round(f.sigma_cagr*100,2)), \
         color = (0.2,0.2,1,1))
plt.plot(f1.sigma, marker="s", mfc='none', ms=12, mew=2, label="High_income({})\nCAGR = {}%".format(f1.dof+1, round(f1.sigma_cagr*100,2)), \
         color = "#FF0000", linestyle = "--")
plt.plot(f2.sigma, marker="^", mfc='none', ms=12, mew=2, lw=3, \
         label="Middle_income({})\nCAGR = {}%".format(f2.dof+1, round(f2.sigma_cagr*100,2)), \
         color = (0.9,0.7,0,1), linestyle = "--")
plt.plot(f3.sigma, marker="o", mfc='none', ms=12, mew=2, lw=3, 
         label="Low_income({})\nCAGR = {}%".format(f3.dof+1, round(f3.sigma_cagr*100,2)), \
         color = (0.5,0.7,0,1), linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(5), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,6.5))
f = ca_total
f1 = ca_high
f2 = ca_middle
f3 = ca_low
plt.plot(f.gamma, marker="D", mew=5, lw=3, label="Total({})\nCAGR = {}%".format(f.dof+1, round(f.gamma_cagr*100,2)), \
         color = (0.2,0.2,1,1))
plt.plot(f1.gamma, marker="s", mfc='none', ms=12, mew=2, label="High_income({})\nCAGR = {}%".format(f1.dof+1, round(f1.gamma_cagr*100,2)), \
         color = "#FF0000", linestyle = "--")
plt.plot(f2.gamma, marker="^", mfc='none', ms=12, mew=2, lw=3, \
         label="Middle_income({})\nCAGR = {}%".format(f2.dof+1, round(f2.gamma_cagr*100,2)), \
         color = (0.9,0.7,0,1), linestyle = "--")
plt.plot(f3.gamma, marker="o", mfc='none', ms=12, mew=2, lw=3, 
         label="Low_income({})\nCAGR = {}%".format(f3.dof+1, round(f3.gamma_cagr*100,2)), \
         color = (0.5,0.7,0,1), linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(6), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,6.5))
f = ca_eap
f1 = ca_ecana
f2 = ca_lac
f3 = ca_mena
f4 = ca_sa
plt.plot(f.sigma, marker="s", mfc='none', ms=12, mew=2, lw=3, label="EAP({})\nCAGR = {}%".format(f.dof+1,round(f.sigma_cagr*100,2)))
plt.plot(f1.sigma, marker="^", mfc='none', ms=12, mew=2, lw=3, label="ECA&NA({})\nCAGR = {}%".format(f1.dof+1,round(f1.sigma_cagr*100,2)), \
         linestyle = "--")
plt.plot(f2.sigma, marker="x", ms=2, mew=15, lw=3, label="LAC({})\nCAGR = {}%".format(f2.dof+1,round(f2.sigma_cagr*100,2))
         , color = (0.5,0.5,0.5,1),linestyle = "--")
plt.plot(f3.sigma, marker="D", mfc='none', ms=12, mew=2, lw=3, label="MENA({})\nCAGR = {}%".format(f3.dof+1,round(f3.sigma_cagr*100,2))
         , color = "#FFBE0A", linestyle = "--")
plt.plot(f4.sigma, marker="+", ms=2, mew=15, lw=3, label="SA({})\nCAGR = {}%".format(f4.dof+1,round(f4.sigma_cagr*100,2)),
         color = "#64CD3C" , linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(7), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches((12,7))
f = ca_eap
f1 = ca_ecana
f2 = ca_lac
f3 = ca_mena
f4 = ca_sa
plt.plot(f.gamma, marker="s", mfc='none', ms=12, mew=2, lw=3, label="EAP({})\nCAGR = {}%".format(f.dof+1,round(f.gamma_cagr*100,2)))
plt.plot(f1.gamma, marker="^", mfc='none', ms=12, mew=2, lw=3, label="ECA&NA({})\nCAGR = {}%".format(f1.dof+1,round(f1.gamma_cagr*100,2)), \
         linestyle = "--")
plt.plot(f2.gamma, marker="x", ms=2, mew=15, lw=3, label="LAC({})\nCAGR = {}%".format(f2.dof+1,round(f2.gamma_cagr*100,2))
         , color = (0.5,0.5,0.5,1),linestyle = "--")
plt.plot(f3.gamma, marker="D", mfc='none', ms=12, mew=2, lw=3, label="MENA({})\nCAGR = {}%".format(f3.dof+1,round(f3.gamma_cagr*100,2))
         , color = "#FFBE0A", linestyle = "--")
plt.plot(f4.gamma, marker="+", ms=2, mew=15, lw=3, label="SA({})\nCAGR = {}%".format(f4.dof+1,round(f4.gamma_cagr*100,2)),
         color = "#64CD3C" , linestyle = "--")
lgd = plt.legend(shadow=True, fancybox=True, loc="lower center", fontsize=12, bbox_to_anchor=(0.5,-0.2), ncol=5)
plt.ylabel('Marine protected areas as a percent of EEZ', size=12)
plt.grid(True, axis='y', alpha=0.6)
plt.savefig("./figure/figure {}.jpg".format(8), dpi=None, facecolor='w', 
           edgecolor='w',orientation='portrait', 
           papertype=None, format=None,transparent=False, 
           bbox_inches="tight", pad_inches=0.1,frameon=None,bbox_extra_artists=(lgd,))
plt.show()

# %%
import sys
mod = sys.modules[__name__]
f = ca_total
f1 = ca_high
f2 = ca_middle
f3 = ca_low

g = f.get_measure_table(name="MPAEEZ",measure="Total({})".format(f.dof+1))
gb = f1.get_measure_table(name="Income",measure="High({})".format(f1.dof+1))
gc = f2.get_measure_table(name="Income",measure="Middle({})".format(f2.dof+1))
ge = f3.get_measure_table(name="Income",measure="Low({})".format(f3.dof+1))
setattr(mod, "table{}".format(1), pd.concat((g,gb,gc,ge), axis=1))
#getattr(mod, "tb{}".format(i)).to_csv("./result/table1/{}_{}_Table1.csv".format(i, v_li[i]))

h = f.get_index_table("Total({})".format(f.dof+1))
hb = f1.get_index_table("High_income({})".format(f1.dof+1))
hc = f2.get_index_table("Middle_income({})".format(f2.dof+1))
he = f3.get_index_table("Low_income({})".format(f3.dof+1))
setattr(mod, "table{}".format(2), pd.concat((h,hb,hc,he), axis=1))
#getattr(mod, "tb2{}".format(i)).to_csv("./result/table2/{}_{}_Table2.csv".format(i, v_li[i]))

# %%
table1
# Out:
#          MPAEEZ   Income
#      Total(104) High(41) Middle(32) Low(31)
# 1990       0.73     0.91       0.91    0.31
# 1991       1.04     1.69       0.91    0.33
# 1992       1.19     1.82       1.15    0.41
# 1993       1.24     1.88       1.18    0.44
# 1994       1.55     2.55       1.34    0.45
# 1995       1.59     2.56       1.42    0.50
# 1996       1.98     3.43       1.48    0.58
# 1997       2.13     3.50       1.56    0.90
# 1998       2.47     3.58       2.57    0.91
# 1999       2.57     3.71       2.70    0.93
# 2000       2.65     3.78       2.73    1.07
# 2001       2.86     3.95       3.09    1.18
# 2002       3.06     4.41       3.13    1.21
# 2003       3.18     4.65       3.17    1.26
# 2004       3.31     4.81       3.22    1.41
# 2005       4.70     8.28       3.24    1.48
# 2006       4.98     8.76       3.45    1.57
# 2007       5.19     8.96       3.46    1.98
# 2008       5.53     9.79       3.47    2.01
# 2009       5.74    10.28       3.47    2.06
# ...

# %%
table2
# Out:
#      Total(104)                             High_income(41)                  \
#           sigma p_value   gamma chi_p_value           sigma p_value   gamma
# 1990     1.0000          1.0000                      1.0000          1.0000
# 1991     1.1632          0.9769         ***          1.2497          0.9663
# 1992     1.0563          0.9643         ***          1.1953          0.9845
# 1993     1.0328          0.9606         ***          1.1698          0.9772
# 1994     1.0489          0.9592         ***          1.1525          0.9787
# 1995     1.0194          0.9519         ***          1.1474          0.9766
# 1996     0.9854          0.9564         ***          1.0453          0.9841
# 1997     0.9288          0.9424         ***          1.0307          0.9662
# 1998     0.9072          0.9119         ***          1.0107          0.9431
# 1999     0.8842          0.9086         ***          0.9891          0.9448
# ...

# %%
f = ca_eap
f1 = ca_ecana
f2 = ca_lac
f3 = ca_mena
f4 = ca_sa

g = f.get_measure_table(name="Region",measure="EAP({})".format(f.dof+1))
gb = f1.get_measure_table(name="Region",measure="ECA&NA({})".format(f1.dof+1))
gc = f2.get_measure_table(name="Region",measure="LAC({})".format(f2.dof+1))
ge = f3.get_measure_table(name="Region",measure="MENA({})".format(f3.dof+1))
go = f4.get_measure_table(name="Region",measure="LAC({})".format(f4.dof+1))
setattr(mod, "idx_table{}".format(1), pd.concat((g,gb,gc,ge,go), axis=1))
#getattr(mod, "tb{}".format(i)).to_csv("./result/table1/{}_{}_Table1.csv".format(i, v_li[i]))

h = f.get_index_table("EAP({})".format(f.dof+1))
hb = f1.get_index_table("ECA&NA({})".format(f1.dof+1))
hc = f2.get_index_table("LAC({})".format(f2.dof+1))
he = f3.get_index_table("MENA({})".format(f3.dof+1))
ho = f4.get_index_table("LAC({})".format(f4.dof+1))
setattr(mod, "idx_table{}".format(2), pd.concat((h,hb,hc,he,ho), axis=1))
#getattr(mod, "tb2{}".format(i)).to_csv("./result/table2/{}_{}_Table2.csv".format(i, v_li[i]))

# %%
idx_table1
# Out:
#       Region
#      EAP(22) ECA&NA(30) LAC(24) MENA(9) LAC(19)
# 1990    0.58       1.18    0.82    0.14    0.35
# 1991    0.62       2.24    0.83    0.14    0.35
# 1992    0.62       2.62    0.99    0.14    0.35
# 1993    0.63       2.73    0.99    0.14    0.41
# 1994    0.63       3.65    1.20    0.15    0.41
# 1995    0.71       3.72    1.23    0.15    0.41
# 1996    0.71       4.94    1.30    0.36    0.42
# 1997    0.77       5.01    1.39    0.41    0.90
# 1998    0.78       5.13    1.40    3.92    0.92
# 1999    0.81       5.35    1.51    3.94    0.92
# 2000    0.93       5.36    1.55    3.98    1.09
# 2001    0.94       5.59    2.05    3.98    1.25
# 2002    1.06       5.87    2.09    4.94    1.30
# 2003    1.12       6.19    2.13    4.94    1.32
# 2004    1.15       6.26    2.17    5.93    1.35
# 2005    1.37      10.86    2.17    5.93    1.46
# 2006    1.48      11.35    2.49    6.36    1.48
# 2007    2.03      11.62    2.49    6.43    1.48
# ...

# %%
idx_table2
# Out:
#      EAP(22)                             ECA&NA(30)                  \
#        sigma p_value   gamma chi_p_value      sigma p_value   gamma
# 1990  1.0000          1.0000                 1.0000          1.0000
# 1991  0.9380          0.9452         ***     1.2348          0.9513
# 1992  0.9352          0.9445         ***     1.0873          0.9558
# 1993  0.9262          0.9438         ***     1.0593          0.9427
# 1994  0.9215          0.9438         ***     1.0470          0.9550
# 1995  0.8239          0.8941         ***     1.0245          0.9511
# 1996  0.8235          0.8941         ***     0.9321          0.9657
# 1997  0.7491          0.8479         ***     0.9261          0.9620
# 1998  0.7385          0.8271         ***     0.9058          0.9436
# 1999  0.7119          0.8160         ***     0.8799          0.9447
# 2000  0.6457          0.8702         ***     0.8772          0.9439
# 2001  0.6388          0.8889         ***     0.8490          0.9502
# ...

# %%
table1.to_csv("table1.csv")
table2.to_csv("table2.csv")
idx_table1.to_csv("idx_table1.csv")
idx_table2.to_csv("idx_table2.csv")

# %%
pd.concat((ca_total.mean, ca_high.mean, ca_middle.mean, ca_low.mean),axis=1, 
          keys=["Total ({})\nCAGR = {}%".format(ca_eap.dof+1, round(ca_total.mean_cagr*100,2)),
                "High ({})\nCAGR = {}%".format(ca_ecana.dof+1, round(ca_high.mean_cagr*100,2)),
                "Middle ({})\nCAGR = {}%".format(ca_lac.dof+1, round(ca_middle.mean_cagr*100,2)),
                "Low ({})\nCAGR = {}%".format(ca_mena.dof+1, round(ca_low.mean_cagr*100,2))]).plot(
    figsize=(7,4), grid=True, marker="o")

# %%
pd.concat((ca_eap.mean, ca_ecana.mean, ca_lac.mean, ca_mena.mean, ca_sa.mean),axis=1, 
          keys=["EAP ({})\nCAGR = {}%".format(ca_eap.dof+1, round(ca_eap.mean_cagr*100,2)),
                "ECA&NA ({})\nCAGR = {}%".format(ca_ecana.dof+1, round(ca_ecana.mean_cagr*100,2)),
                "LAC ({})\nCAGR = {}%".format(ca_lac.dof+1, round(ca_lac.mean_cagr*100,2)),
                "MENA ({})\nCAGR = {}%".format(ca_mena.dof+1, round(ca_mena.mean_cagr*100,2)),
                "SA ({})\nCAGR = {}%".format(ca_sa.dof+1, round(ca_sa.mean_cagr*100,2))]).plot(
    figsize=(7,4), grid=True, marker="o")
